# %% [markdown]
# Trying more current data from sfgov.org

# %%
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.11/dist-packages (from sodapy) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->sodapy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->sodapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->sodapy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->sodapy) (2025.4.26)
# Downloading sodapy-2.2.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.2.0

# %% [markdown]
# Loading the data

# %%
from google.colab import userdata
from sodapy import Socrata
import pandas as pd

# Load credentials
DATASFAPI = userdata.get('apptoken')
username = userdata.get('username')  # Optional, needed if app token access is restricted
password = userdata.get('password')

# Initialize client
client = Socrata("data.sfgov.org", DATASFAPI, username=username, password=password)

# Parameters
dataset_id = "wg3w-h783"  # Use the correct dataset ID from your provided URL
chunk_size = 10000
offset = 0
all_results = []

# Paginate through results
while True:
    chunk = client.get(dataset_id, limit=chunk_size, offset=offset)
    if not chunk:
        break
    all_results.extend(chunk)
    offset += chunk_size
    print(f"Retrieved {offset} records...")

# Convert to DataFrame
crime = pd.DataFrame.from_records(all_results)
print(f"Total records retrieved: {len(crime)}")
# Out:
# Retrieved 10000 records...
# Retrieved 20000 records...
# Retrieved 30000 records...
# Retrieved 40000 records...
# Retrieved 50000 records...
# Retrieved 60000 records...
# Retrieved 70000 records...
# Retrieved 80000 records...
# Retrieved 90000 records...
# Retrieved 100000 records...
# Retrieved 110000 records...
# Retrieved 120000 records...
# Retrieved 130000 records...
# Retrieved 140000 records...
# Retrieved 150000 records...
# Retrieved 160000 records...
# Retrieved 170000 records...
# Retrieved 180000 records...
# Retrieved 190000 records...
# Retrieved 200000 records...
# Retrieved 210000 records...
# Retrieved 220000 records...
# Retrieved 230000 records...
# Retrieved 240000 records...
# Retrieved 250000 records...
# Retrieved 260000 records...
# Retrieved 270000 records...
# Retrieved 280000 records...
# Retrieved 290000 records...
# Retrieved 300000 records...
# Retrieved 310000 records...
# Retrieved 320000 records...
# Retrieved 330000 records...
# Retrieved 340000 records...
# Retrieved 350000 records...
# Retrieved 360000 records...
# Retrieved 370000 records...
# Retrieved 380000 records...
# Retrieved 390000 records...
# Retrieved 400000 records...
# Retrieved 410000 records...
# Retrieved 420000 records...
# Retrieved 430000 records...
# Retrieved 440000 records...
# Retrieved 450000 records...
# Retrieved 460000 records...
# Retrieved 470000 records...
# Retrieved 480000 records...
# Retrieved 490000 records...
# Retrieved 500000 records...
# Retrieved 510000 records...
# Retrieved 520000 records...
# Retrieved 530000 records...
# Retrieved 540000 records...
# Retrieved 550000 records...
# Retrieved 560000 records...
# Retrieved 570000 records...
# Retrieved 580000 records...
# Retrieved 590000 records...
# Retrieved 600000 records...
# Retrieved 610000 records...
# Retrieved 620000 records...
# Retrieved 630000 records...
# Retrieved 640000 records...
# Retrieved 650000 records...
# Retrieved 660000 records...
# Retrieved 670000 records...
# Retrieved 680000 records...
# Retrieved 690000 records...
# Retrieved 700000 records...
# Retrieved 710000 records...
# Retrieved 720000 records...
# Retrieved 730000 records...
# Retrieved 740000 records...
# Retrieved 750000 records...
# Retrieved 760000 records...
# Retrieved 770000 records...
# Retrieved 780000 records...
# Retrieved 790000 records...
# Retrieved 800000 records...
# Retrieved 810000 records...
# Retrieved 820000 records...
# Retrieved 830000 records...
# Retrieved 840000 records...
# Retrieved 850000 records...
# Retrieved 860000 records...
# Retrieved 870000 records...
# Retrieved 880000 records...
# Retrieved 890000 records...
# Retrieved 900000 records...
# Retrieved 910000 records...
# Retrieved 920000 records...
# Retrieved 930000 records...
# Retrieved 940000 records...
# Retrieved 950000 records...
# Retrieved 960000 records...
# Retrieved 970000 records...
# Total records retrieved: 961180

# %%
#data types of crime columns

crime.dtypes
# Out:
# incident_datetime              object
# incident_date                  object
# incident_time                  object
# incident_year                  object
# incident_day_of_week           object
# report_datetime                object
# row_id                         object
# incident_id                    object
# incident_number                object
# report_type_code               object
# report_type_description        object
# incident_code                  object
# incident_category              object
# incident_subcategory           object
# incident_description           object
# resolution                     object
# police_district                object
# cad_number                     object
# intersection                   object
# cnn                            object
# analysis_neighborhood          object
# supervisor_district            object
# supervisor_district_2012       object
# latitude                       object
# longitude                      object
# point                          object
# :@computed_region_jwn9_ihcz    object
# :@computed_region_26cr_cadq    object
# :@computed_region_qgnn_b9vv    object
# filed_online                   object
# :@computed_region_nqbw_i6c3    object
# :@computed_region_h4ep_8xdi    object
# :@computed_region_jg9y_a9du    object
# :@computed_region_n4xg_c4py    object
# dtype: object

# %%
crime.iloc[1, :]

# %% [markdown]
# # Cleaning the Data

# %%
# truncate before data before 2022
crime = crime[crime['incident_datetime'] >= '2022-01-01T00:00:00.000']

# %%
# since not useful we're going to remove the rows with NAN longitude and latitude
crime = crime.dropna(subset=['latitude', 'longitude'])

# %%
crime = crime.dropna(subset=['incident_datetime', 'latitude', 'longitude'])

# %%
# count how many rows have neighborhoods attached
print((crime['analysis_neighborhood'] == 'null').sum())
# Correctly call the .isna() method on the Series and then .sum()
print(crime['analysis_neighborhood'].isna().sum())
# Out:
# 22
# 76

# %%
# remove the na's and 'null's from crime data set column analysis_neighborhood

crime = crime[(crime['analysis_neighborhood'] != 'null') & (crime['analysis_neighborhood'].notna())]
print("Length after removing 'null' and NA:", len(crime))
# Out:
# Length after removing 'null' and NA: 392696

# %%
# remove last 7 columns from data and row_id, point, and supervisor
crime = crime.drop(columns=['row_id', 'point', 'supervisor_district_2012', 'cnn', ':@computed_region_jwn9_ihcz', ':@computed_region_26cr_cadq', ':@computed_region_qgnn_b9vv', ':@computed_region_nqbw_i6c3', ':@computed_region_h4ep_8xdi', ':@computed_region_n4xg_c4py', ':@computed_region_jg9y_a9du'])

# %%
print("new length of data", len(crime))
# Out:
# new length of data 390985

# %%
crime.iloc[1, :]
# Out:
# incident_datetime          2024-06-25T17:45:00.000
# incident_date              2024-06-25T00:00:00.000
# incident_time                                17:45
# incident_year                                 2024
# incident_day_of_week                       Tuesday
# report_datetime            2024-06-26T13:08:00.000
# incident_id                                1401726
# incident_number                          240398241
# report_type_code                                II
# report_type_description                    Initial
# incident_code                                04104
# incident_category                          Assault
# incident_subcategory                Simple Assault
# incident_description       Assault, Non-Aggravated
# resolution                          Open or Active
# police_district                           Northern
# cad_number                               241781437
# intersection                   EDDY ST \ PIERCE ST
# analysis_neighborhood             Western Addition
# supervisor_district                              5
# latitude                        37.781009674072266
# longitude                      -122.43561553955078
# filed_online                                   NaN
# Name: 18, dtype: object

# %% [markdown]
# # EDA

# %%
# prompt: create a heatmap using crime dataset latitude and longiitude where I can filter the data for timeframe through the ['incident_datetime'] column, the incident_category column

# !pip install folium
import folium
from folium.plugins import HeatMap

# Convert latitude and longitude to numeric
crime['latitude'] = pd.to_numeric(crime['latitude'])
crime['longitude'] = pd.to_numeric(crime['longitude'])

# Convert incident_datetime to datetime objects
crime['incident_datetime'] = pd.to_datetime(crime['incident_datetime'])

def create_crime_heatmap(dataframe, start_date=None, end_date=None, incident_category=None):
    """
    Creates a heatmap of crime incidents with optional filtering.

    Args:
        dataframe (pd.DataFrame): The crime data DataFrame.
        start_date (str, optional): Start date for filtering (YYYY-MM-DD). Defaults to None.
        end_date (str, optional): End date for filtering (YYYY-MM-DD). Defaults to None.
        incident_category (str, optional): Incident category to filter by. Defaults to None.

    Returns:
        folium.Map: The Folium map object with the heatmap layer.
    """
    # Filter the dataframe based on parameters
    filtered_df = dataframe.copy()
    if start_date:
        filtered_df = filtered_df[filtered_df['incident_datetime'] >= start_date]
    if end_date:
        filtered_df = filtered_df[filtered_df['incident_datetime'] <= end_date]
    if incident_category:
        filtered_df = filtered_df[filtered_df['incident_category'] == incident_category]

    # Ensure there are data points after filtering
    if filtered_df.empty:
        print("No data points found for the selected filters.")
        # Create a base map even if empty
        m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
        return m

    # Create a list of latitude and longitude pairs for the heatmap
    heat_data = filtered_df[['latitude', 'longitude']].values.tolist()

    # Create a base map centered around the San Francisco area
    m = folium.Map(location=[filtered_df['latitude'].mean(), filtered_df['longitude'].mean()], zoom_start=12)

    # Add the heatmap layer
    HeatMap(heat_data).add_to(m)

    return m

# Example Usage:

# Create a heatmap for all data
#all_crime_heatmap = create_crime_heatmap(crime)
#all_crime_heatmap

# Create a heatmap for a specific time frame
#imeframe_heatmap = create_crime_heatmap(crime, start_date='2023-01-01', end_date='2023-12-31')
#timeframe_heatmap

# Create a heatmap for a specific incident category
#category_heatmap = create_crime_heatmap(crime, incident_category='Larceny Theft')
#category_heatmap
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.6)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.4.26)

# %% [markdown]
# ['Lost Property' 'Other Miscellaneous' 'Other' 'Assault' 'Non-Criminal'
#  'Disorderly Conduct' 'Missing Person' 'Fire Report' 'Suspicious Occ'
#  'Arson' 'Larceny Theft' 'Robbery' 'Burglary' 'Traffic Violation Arrest'
#  'Warrant' 'Offences Against The Family And Children' 'Recovered Vehicle'
#  'Weapons Carrying Etc' 'Drug Offense' 'Malicious Mischief' 'Fraud'
#  'Miscellaneous Investigation' 'Stolen Property' 'Motor Vehicle Theft'
#  'Vandalism' 'Case Closure' 'Courtesy Report' 'Weapons Offense'
#  'Other Offenses' 'Traffic Collision' 'Forgery And Counterfeiting'
#  'Homicide' 'Suicide' 'Embezzlement' 'Drug Violation' 'Vehicle Impounded'
#  nan 'Prostitution' 'Sex Offense' 'Vehicle Misplaced' 'Rape'
#  'Motor Vehicle Theft?' 'Liquor Laws'
#  'Human Trafficking (A), Commercial Sex Acts' 'Civil Sidewalks'
#  'Suspicious' 'Gambling' 'Human Trafficking, Commercial Sex Acts'
#  'Weapons Offence' 'Human Trafficking (B), Involuntary Servitude']

# %%
# print unique report_type_description
print(crime['report_type_description'].unique())
# Out:
# ['Initial' 'Coplogic Initial' 'Initial Supplement' 'Vehicle Initial'
#  'Vehicle Supplement' 'Coplogic Supplement']

# %%
# print unique incident category
print(crime['incident_category'].unique())
# Out:
# ['Other Miscellaneous' 'Assault' 'Larceny Theft' 'Fraud'
#  'Malicious Mischief' 'Motor Vehicle Theft' 'Suspicious Occ' 'Warrant'
#  'Recovered Vehicle' 'Burglary' 'Missing Person' 'Drug Offense'
#  'Non-Criminal' 'Traffic Collision' 'Other Offenses' 'Lost Property'
#  'Robbery' 'Stolen Property' 'Disorderly Conduct' 'Weapons Offense'
#  'Offences Against The Family And Children' 'Forgery And Counterfeiting'
#  'Vehicle Misplaced' 'Other' 'Miscellaneous Investigation'
#  'Traffic Violation Arrest' nan 'Courtesy Report' 'Weapons Carrying Etc'
#  'Arson' 'Fire Report' 'Prostitution' 'Case Closure' 'Homicide' 'Suicide'
#  'Vehicle Impounded' 'Embezzlement' 'Sex Offense' 'Rape' 'Vandalism'
#  'Drug Violation' 'Motor Vehicle Theft?' 'Liquor Laws'
#  'Human Trafficking (A), Commercial Sex Acts'
#  'Human Trafficking, Commercial Sex Acts' 'Suspicious' 'Civil Sidewalks'
#  'Gambling' 'Weapons Offence'
#  'Human Trafficking (B), Involuntary Servitude']

# %%
# print unique incident sub category
print(crime['incident_subcategory'].unique())
# Out:
# ['Lost Property' 'Other' 'Simple Assault' 'Trespass' 'Non-Criminal'
#  'Intimidation' 'Missing Adult' 'Aggravated Assault' 'Missing Person'
#  'Fire Report' 'Suspicious Occ' 'Arson' 'Larceny Theft - Other'
#  'Robbery - Other' 'Burglary - Other' 'Larceny Theft - Shoplifting'
#  'Traffic Violation Arrest' 'Larceny Theft - From Building'
#  'Theft From Vehicle' 'Stalking' 'Recovered Vehicle'
#  'Larceny - From Vehicle' 'Weapons Offense' 'Drug Violation' 'Drunkenness'
#  'Robbery - Commercial' 'Vandalism' 'Fraud' 'Miscellaneous Investigation'
#  'Stolen Property' 'Motor Vehicle Theft' 'Warrant' 'Larceny - Auto Parts'
#  'Case Closure' 'Courtesy Report' 'Traffic Collision'
#  'Burglary - Residential' 'Larceny Theft - Pickpocket' 'Kidnapping'
#  'Loitering' 'Forgery And Counterfeiting' 'Robbery - Street'
#  'Burglary - Hot Prowl' 'Disorderly Conduct' 'Homicide' 'Suicide'
#  'Liquor Law Violation' 'Embezzlement' 'Burglary - Commercial'
#  'Other Offenses' 'Vehicle Impounded' nan 'Prostitution'
#  'Traffic Collision - Hit & Run' 'Larceny Theft - Bicycle' 'Sex Offense'
#  'Extortion-Blackmail' 'Vehicle Misplaced'
#  'Motor Vehicle Theft (Attempted)' 'Robbery - Carjacking' 'Rape'
#  'Manslaughter' 'Human Trafficking, Commercial Sex Acts'
#  'Rape - Attempted' 'Larceny Theft - Purse Snatch' 'Bribery'
#  'Robbery - Residential' 'Suspicious Package' 'Gambling' 'Bad Checks'
#  'Human Trafficking, Involuntary Servitude' 'Homicide - Excusable'
#  'Arrest']

# %%
# print unique incident description
print(crime['incident_description'].unique())
# no nlp yet
# Out:
# ['Lost Property' 'Conspiracy' 'Death Report, Cause Unknown' 'Battery'
#  'Trespassing' 'Found  Property' 'Terrorist Threats' 'Missing Adult'
#  'Assault, Aggravated, W/ Other Weapon' 'Found Person' 'Fire Report'
#  'Aided Case' 'Suspicious Occurrence' 'Mental Health Detention' 'Arson'
#  'Theft, Other Property, >$950' 'Robbery, W/ Gun'
#  'Burglary, Other Bldg., Unlawful Entry' 'Theft, Shoplifting, <$50'
#  'Traffic Violation Arrest' 'Theft, From Building, $200-$950'
#  'Warrant Arrest, Local SF Warrant' 'License Plate, Stolen'
#  'Battery, Of A Police Officer' 'Burglary, Other Bldg., Forcible Entry'
#  'Stalking' 'Vehicle, Recovered, Motorcycle'
#  'Theft, From Locked Vehicle, >$950' 'Investigative Detention'
#  'Firearm, Possession By Prohibited Person'
#  'Theft, From Unlocked Vehicle, >$950' 'Search Warrant Service'
#  'Methamphetamine Offense' 'Driving, No License Issued'
#  'Alcohol, Under Influence Of In Public Place'
#  'Shoplifting, Force against Agent'
#  'Malicious Mischief, Vandalism to Vehicle'
#  'Aided case, Naloxone Deployment' 'Assault, Non-Aggravated'
#  'Theft, Other Property, $50-$200'
#  'Battery, former Spouse or Dating Relationship'
#  'Access Card, incl. Credit, Phone, ATM, Fraudulent Use of'
#  'Domestic Violence (secondary only)' 'Robbery, W/ Force'
#  'Theft, Shoplifting, $50-$200'
#  'Threat or Force to Resist Executive Officer'
#  'Narcotics Paraphernalia, Possession of' 'Miscellaneous Investigation'
#  'Vehicle, Recovered, Other Vehicle'
#  'Stolen Cellular Phone, non-cloned, Possession' 'Vehicle, Stolen, Auto'
#  'Malicious Mischief, Vandalism to Property'
#  'Firearm, Turned In by Public'
#  'Warrant Arrest, Enroute To Outside Jurisdiction'
#  'Assault, Aggravated, W/ Force' 'Assault, Aggravated, W/ Knife'
#  'Vehicle, Tampering' 'Vehicle, Recovered, Stolen outside SF'
#  'Probation Violation' 'Theft, Motorcycle Strip, >$950'
#  'False Personation to Receive Money or Property'
#  'Violation of Restraining Order' 'Robbery, Chain Store, W/ Force'
#  'Theft, Shoplifting, $200-$950' 'Case Closure' 'Dog, Bite or Attack'
#  'Theft, From Locked Vehicle, $200-$950' 'Hate Crime (secondary only)'
#  'Battery, Sexual' 'Courtesy Report'
#  'Controlled Substance Violation, Loitering for'
#  'Weapon, Deadly, Imitation or Laser Scope, Exhibiting'
#  'False Personation and Cheat Crimes (general)'
#  'Resisting, Delaying, or Obstructing  Peace Officer Duties'
#  'Vehicle, Recovered, Auto' 'Burglary, Non-residential, Forcible Entry'
#  'Stay Away or Court Order, Non-DV Related'
#  'Restraining Order Notification/Service of Restraining Order'
#  'Municipal Code Violation (general)' 'Traffic Collision'
#  'Burglary, Apartment House, Forcible Entry' 'Theft, Pickpocket, $50-$200'
#  'False Imprisonment' 'False Personation'
#  'Loitering Where Narcotics are Sold/Used'
#  'Theft, Other Property, $200-$950'
#  'Drugs, Under Influence  in a Public Place'
#  'Burglary, Residence, Unlawful Entry' 'Impersonating A Police Officer'
#  'Lodging Without Permission' 'Burglary, Residence, Forcible Entry'
#  'Forgery & Counterfeiting (general)' 'Arson of Vehicle'
#  'Opiates, Possession For Sale'
#  'Robbery, Street or Public Place, W/ Knife'
#  'Evading a Police Officer Recklessly' 'Theft, Shoplifting, >$950'
#  'Burglary, Hot Prowl, Unlawful Entry'
#  'Robbery, Street or Public Place, W/ Other Weapon' 'Disturbing The Peace'
#  'Parole Violation, Adult' 'Phone Calls, Threatening or Annoying'
#  'Homicide' 'Theft, From Unlocked Vehicle, $50-$200'
#  'Theft, From Building, $50-$200'
#  'Checks, Blank or Forged, Fraudulent Possession' 'Suicide, Attempted'
#  'Controlled Substance Offense' 'Warrant Arrest, Enroute To US Marshall'
#  'Malicious Mischief, Graffiti, Real or Personal Property'
#  'Assault, Aggravated, On Police Off., W/ Other Weapon'
#  'Robbery, Street or Public Place, W/ Force' 'Vehicle, Stolen & Recovered'
#  'Kidnapping (Adult victim)' 'Theft, Petty, with Prior Conviction'
#  'Driving While Under The Influence Of Drugs'
#  'Theft, From Building, >$950' 'Aided Case, Injured or Sick Person'
#  'Firearm, Possession of Loaded'
#  'Controlled Substance, Under the Influence of'
#  'Methamphetamine, Possession For Sale'
#  'Aided Case -Property for Destruction'
#  'Burglary, Apartment House, Att. Forcible Entry'
#  'Driving While Under The Influence Of Alcohol, w/Injury'
#  'Warrant Arrest, Enroute To Adult Authority'
#  'Vandalism or Graffiti on or within 100 ft of Highway'
#  'Burglary, Non-residential, Unlawful Entry' 'Robbery, W/ Other Weapon'
#  'Driving, License Suspended or Revoked' 'Robbery, Att., W/ Force'
#  'Vehicle, Embezzled'
#  'Stolen Property, Possession with Knowledge, Receiving'
#  'Burglary Tools, Possession Of' 'Burglary, Store, Forcible Entry'
#  'Burglary, Apartment House, Unlawful Entry'
#  'Money, Property or Labor, Fraudulently Obtaining'
#  'Fraudulent Game or Trick, Obtaining Money or Property'
#  'Flammable or Explosive Device, Possession'
#  'Firearm, Armed While Possessing Controlled Substance'
#  'License Plate, Found' 'Theft, From Unlocked Vehicle, <$50'
#  'Theft, From Person, >$950 (other than Pickpocket)'
#  'Theft, From Locked Vehicle, $50-$200'
#  'False Claims, Presenting to Government'
#  'Burglary, Other Bldg., Att. Forcible Entry' 'Arson, Inhabited Dwelling'
#  'Theft, Lost Property, Petty' 'Robbery, Street or Public Place, W/ Gun'
#  'Vehicle, Impounded' 'Burglary, Apt Under Constr., Forcible Entry'
#  'Burglary, Residence, Att. Forcible Entry' 'Vehicle, Stolen, Motorcycle'
#  'Battery with Serious Injuries' 'License Plate, Recovered'
#  'Suspicious Act Towards Female'
#  'Cryptocurrency Related Crime (secondary code only)' 'Death, Accidental'
#  'Gang Related (secondary only)' 'Driving, Reckless'
#  'Shooting into Inhabited Dwelling or Occupied Vehicle'
#  'Air Gun, Possession' 'Cocaine Offense' 'Vehicle, Stolen, Other Vehicle'
#  'Warrant Arrest, Enroute To Probation' 'Vehicle, Seizure Order Service'
#  'Solicits For Act Of Prostitution'
#  'Burglary, Hot Prowl, Att. Forcible Entry'
#  'Defrauding Providers of Food, Fuel, Services, or Accommodations'
#  'Malicious Mischief, Breaking Windows'
#  'Traffic Collision, Hit & Run, Property Damage' 'Theft, Bicycle, >$950'
#  'Indecent Exposure (Adult victim)'
#  'Cocaine, Base/rock, Possession For Sale'
#  'Warrant Arrest, Enroute To Parole'
#  'Theft, From Person, $50-$200 (other than Pickpocket)'
#  'Vehicle, Stolen, Truck' 'Evading a Police Vehicle or Bicycle'
#  'ATM-related Crime (secondary code only)'
#  'Warrant Arrest, Enroute To Dept. Of Corrections'
#  'Theft, From Locked Vehicle, Att.' 'Theft, Other Property, <$50'
#  'Theft, Pickpocket, >$950' 'Theft, From Building, <$50'
#  'House of Prostitution, Keeping or Residing in'
#  'Theft, Lost Property, Grand' 'Heroin, Possession For Sale'
#  'License Plate or Tab, Theft of' 'Extortion, Attempted'
#  'Checks, False, Making, Uttering or Possessing' 'Opium Offense'
#  'Checks or Legal Instruments, Uttering Forged'
#  'Sex Offender Failure to Register, Transient Violation'
#  'Vehicle, Misplaced' 'Robbery, Att., Comm. Establ., W/ Gun'
#  'Theft, From Person, <$50 (other than Pickpocket)'
#  'Burglary, Residence Under Constr, Forcible Entry'
#  'Computer System, Accessing, Copying, or Damaging' 'Marijuana, Sales'
#  'Malicious Mischief, Street Cars/Buses' 'Cocaine, Base/rock Offense'
#  'Theft, From Unlocked Vehicle, $200-$950'
#  'Theft of Checks or Credit Cards'
#  'Firearm, Discharging in Grossly Negligent Manner'
#  'Theft, Vehicle Strip, >$950' 'Assault, Att. Homicide, W/ Gun'
#  'Phone Calls, Harassing' 'Vandalism or Graffiti Tools, Possession'
#  'Assault, W/ Caustic Chemical to Injure or Disfigure'
#  'Controlled Substance, Sale'
#  'Firearm, Discharging at Unoccupied Bldg, Vehicle or Aircraft'
#  'Property for Identification' 'Cocaine, Possession For Sale'
#  'Robbery, Comml. Establ., W/ Gun' 'Burglary, Vehicle (Arrest made)'
#  'Vehicle, Stolen, Attempted' 'Public Nuisance, Committing'
#  'Burglary, Non-residential, Att. Forcible'
#  'Burglary, Hot Prowl, Forcible Entry' 'State Code Felony (general)'
#  'Identification To Peace Officer, False' 'Opiates Offense'
#  'Disturbing The Peace, Fighting' 'Burglary, Store, Unlawful Entry'
#  'Robbery, Att., W/ Knife'
#  'Sex Offender Failure to Register, Annual Violation' 'Unlawful Assembly'
#  'Robbery, W/ Knife'
#  'Theft, From Person, $200-$950 (other than Pickpocket)'
#  'Alcohol, Consuming In Public View'
#  'Traffic Collision, Hit & Run, Injury'
#  'Injuring Phone, Cable TV, or Other Line'
#  'Theft, From Locked Vehicle, <$50' 'Theft, Pickpocket, <$50'
#  'Vehicle, Recovered, Truck' 'Extortion or Blackmail' 'Opiates, Sale'
#  'Methamphetamine, Sale' 'Forgery, Checks, Felony'
#  'Embezzlement from Dependent or Elder Adult by Caretaker'
#  'Firearm, Discharging Within City Limits'
#  'Bomb Threat or False Report of Bomb'
#  'Robbery, Chain Store, W/ Other Weapon' 'Arson, Attempted'
#  'Theft, Pickpocket, $200-$950'
#  'Evading a Police Officer, Injury or Death'
#  'Sex Offender, Failure To Register for Sexual Assault of Adult'
#  'Burglary, Safe,  Residence'
#  'Driving While Under The Influence Of Alcohol'
#  'Malicious Mischief, Tire Slashing'
#  'Burglary, Hotel Room, Forcible Entry' 'Theft, Bicycle, $200-$950'
#  'Controlled Substance, Possession For Sale' 'Probation Search'
#  'Burglary, Residence Under Constr, Unlawful Entry'
#  'Firearm, Carrying Loaded with Intent to Commit Felony'
#  'Carjacking with Bodily Force' 'Credit Application, Fraudulent'
#  'VIN Switch' 'Theft, Shoplifting, Att.'
#  'School Grounds, Entry by Sex Offender'
#  'Checks, Making or Uttering with Insufficient Funds'
#  'Firearm, Loaded, in Vehicle, Possession or Use'
#  'Violation of Stay Away Order' 'Oral Copulation, Unlawful (Adult Victim)'
#  'Incident On School Grounds' 'Malicious Mischief, Adult Suspect'
#  'Assault, Aggravated, W/ Gun'
#  'Loitering Without Lawful Business With Owner or Occupant'
#  'Hallucinogenic, Sale' 'Weapon, Carrying Concealed'
#  'Access Card Information, Theft of' 'Assault, Non-Aggravated, Att.'
#  'Death Report, Natural Causes' 'Gun Violence Restraining Order'
#  'Embezzlement, Petty Theft' 'Burglary, Store, Att. Forcible Entry'
#  'Marijuana, Possession For Sale' 'Ammunition, Poss. By Prohibited Person'
#  'Suspicious Person' 'Fraudulent Use Of Automated Teller Card'
#  'Theft from Merchant or Library' 'Robbery, Att., Chain Store, W/ Force'
#  'Burglary, Flat, Forcible Entry'
#  'Weapon, Carrying Concealed with Felony or Narcotics Conviction'
#  'Methadone, Possession For Sale'
#  'Theft, Grand, by Fiduciary, >$950 in 12 months'
#  'Theft, Trick And Device, Att.' 'Counterfeit Money or Coins'
#  'Animal, Cruelty to' 'Vehicle, Rental, Failure to Return'
#  'Interfering, W/ Police Officer'
#  'Theft, From Person, Att. (other than Pickpocket)'
#  'State Code Misdemeanor (general)' 'Engaging In Lewd Act'
#  'Embezzlement, Grand Theft By Employee' 'Homicide, W/ Gun'
#  'Weapon, Prohibited, Possession, Sale, Mfg., Import'
#  'Littering or Dumping that Creates Traffic Hazard'
#  'Rape, Forcible, W/ Force' 'Hallucinogenic,  Possession For Sale'
#  'Theft, False Pretenses, Felony' 'Theft, Vehicle Strip, $200-$950'
#  'Theft, Drunk Roll, $200-$950' 'Falsification of Medical Records'
#  'Sex Offender Petition to Terminate Registration' 'License Plate, Lost'
#  'Indecent Exposure, W/ Prior Conviction'
#  'Checks, Money Orders, Completed, Fraudulent Possession'
#  'Fireworks, Exploding' 'Robbery, Att., Street or Public Place, W/ Force'
#  'Switchblade Knife, Possession'
#  'EPO or Restraining Order Violation, DVU related'
#  'Theft, From Building, Att.' 'Vehicle Registration, False Evidence of'
#  'Firearm with Altered Identification'
#  'Weapon, Deadly, Carrying with Intent to Commit Assault'
#  'Tarasoff Report'
#  'Discharging Offensive or Injurious Substance in Public Area'
#  'Amphetamine, Sale' 'Amphetamine, Possession For Sale'
#  'Theft of Animals (general)' 'Suspicious Vehicle'
#  'Throwing Injurious Substance on Highway'
#  'Theft, Trick And Device, Felony' 'Phone Calls, Threatening' 'Escapes'
#  'Fire Alarm, False' 'Weapon, Assault, Possession, Manufacture, or Sale'
#  'Burglary, Flat, Att. Forcible Entry' 'Burglary, Safe, Other'
#  'Firearm, Discharging at Occupied Bldg, Vehicle, or Aircraft'
#  'Public Nuisance, Maintaining After Notification'
#  'Kidnapping, Attempted (Adult victim)'
#  'Driving, Stunt Vehicle/Street Racing' 'Park Code Violation (general)'
#  'Robbery,  ATM, Gun, Att.' 'Obscene Matter (general)'
#  'Graffiti on Government Vehicles or Public Transportation'
#  'Stay Away Order Violation, DVU related' 'Taxi Fare, Overcharging'
#  'Privacy, Invasion of  (general)'
#  'Burglary, Residence Under Constr, Att. Forcible'
#  'Suspicious Occurrence, possible Shots Fired'
#  'Theft of Other Property, Att.' 'Robbery, Service Station, W/ Gun'
#  'Kidnapping during Robbery' 'Auto, Grand Theft of'
#  'Municipal Police Code Violation (general)' 'Manslaughter, Vehicular'
#  'Sex Offender, Misc. Investigation' 'Alcohol, License Required To Sell'
#  'Robbery, Comml. Establ., W/ Force'
#  'Vehicle, Stolen, Mobile Home or House Trailer' 'Auto Impounded'
#  'Defrauding Gas Station/Taxi Driver' 'False Report of Emergency'
#  'Robbery, Service Station W/ Other Weapon' 'Opium Derivative Offense'
#  'Opiates, Transportation' 'Unusual Occurrence' 'Amphetamines Offense'
#  'Disturbing The Peace, Commotion' 'Phone Calls, Harassing, to 911'
#  'Theft, False Pretenses, Misd.' 'Robbery, Chain Store, W/ Knife'
#  'Opium Derivative, Possession For Sale'
#  'Burglary, Warehouse, Att. Forcible Entry'
#  'Firearm, Discharging At An Inhabited Dwelling'
#  'Malicious Mischief, Breaking Windows With BB Gun'
#  'Soliciting or Engaging In Lewd Conduct'
#  'Robbery, Att., Comm. Establ., W/ Force' 'Fire, Unlawfully Causing'
#  'Cellular or Cordless Phone Communications, Intercepting'
#  'Theft of Utility Services' 'SFMTA Muni Transit Operator-Bus/LRV'
#  'Audiovisual (Video or Sound) Recordings, Unauthorized'
#  'Human Trafficking (A)-Commercial Sex Acts'
#  'Penetration, Forced, with Object'
#  'Malicious Mischief, Building Under Constr.'
#  'Federal Law Violation (general)' 'Aided Case, Sick Person'
#  'School Campus, Remaining Without Consent'
#  'Resisting Peace Officer, causing Their Serious Injury or Death'
#  'Theft, Coin Operated Machine, $200-$950'
#  'Burglary, Other Bldg. Under Constr., Forcible Entry'
#  'Identification, Government, Possess, Make or Sell False'
#  'Burglary, Warehouse, Forcible Entry' 'Assault During Labor Dispute'
#  'Marijuana Offense' 'Weapon, Possess or Bring Other on School Grounds'
#  'Theft, Vehicle Strip, Attempted' 'Robbery,  ATM, Gun'
#  'Rape, Assault To, W/ Force'
#  'Robbery, Att., Street or Public Place, W/ Knife'
#  'Robbery,  ATM, Knife, Att.' 'Violation of Emergency Protective Order'
#  'Theft of Telecommunication Services, incl. Clone Phone'
#  'Counterfeit Coins Or Notes, Possessing or Receiving'
#  'Theft, From Unlocked Vehicle, Att.' 'Burglary, Safe,  Store'
#  'Vehicle Alarm Code Grabbing Device, Possess or Use'
#  'Theft of Computers or Cell Phones' 'Carjacking with a Knife'
#  'Robbery, Att., Street or Public Place, W/ Other Weapon'
#  'Access Card, Possession of Lost or Stolen, with Intent to Use, Transfer, or Sell'
#  'Civil Sidewalks, Warning'
#  'Access Card Counterfeiting Machinery, Possession of'
#  'Embezzlement, Grand Theft' 'Theft, Short Change'
#  'Burglary, Flat, Unlawful Entry'
#  'Assault, Aggravated, On Police Officer, W/ Gun'
#  'Theft, Purse Snatch, <$50' 'School Property, Disturbance on'
#  'Robbery, Att., W/ Gun'
#  'Burglary, Other Bldg. Under Constr., Unlawful Entry'
#  'Burglary, Apt Under Constr., Unlawful Entry'
#  'Arson, Commercial Building' 'Real Estate Fraud'
#  'Assault, Aggravated, On Police Officer, W/ Knife'
#  'Drug Offender, Presence  near School Grounds'
#  'Robbery, Comml. Establ. W/ Weapon' 'Theft, Drunk Roll, >$950'
#  'Carjacking with a Gun' 'Machine Gun or Sawed-off Shotgun, Possession'
#  'Disturbing The Peace, Swearing'
#  'Disaster Area, Entering or Remaining in' 'Explosive Device, Located'
#  'Embezzlement (general)' 'Sexual Assault, Administering Drug to Commit'
#  'Refusing To Disperse Upon Lawful Command' 'School, Disrupt Activities'
#  'Dog or Cat, Abandonment of'
#  'Conceal Crime or Withhold Evidence, Accepting Payment to'
#  'Civil Sidewalks, Booking' 'Parole Search'
#  'Burglary, Warehouse, Unlawful Entry'
#  'Weapon, Tear Gas, Possession by Prohibited Persons'
#  'Post Release Community Supervision' 'Theft, Coin Operated Machine, Att.'
#  'Vehicle, Recovered, Mobile Home or House Trailer' 'Driving, Speeding'
#  'Robbery, Att., Street or Public Place, W/ Gun' 'Damage To Mail Box'
#  'Located Property' 'False Report of Felony or Misdemeanor'
#  'Letters, Opening Sealed' 'Theft, Bicycle, $50-$200'
#  'Identification Card or Drivers License, Falsify or Display'
#  'Robbery, Att., Residence, W/ Gun' 'Cocaine, Base/rock, Sale'
#  'Food Stamps, Misuse of' 'Dissuading Witness, Victim'
#  'Suspicious Package' 'Robbery, Att., Chain Store, W/ Gun'
#  'Robbery, Chain Store, W/ Gun' 'Suicide By Strangulation/Hanging'
#  'Theft, Bicycle, <$50, no serial number'
#  'Burglary, Vehicle, Att. (Arrest made)'
#  'Burglary, Other Bldg. Under Constr., Att. Forcible'
#  'Arson, Portable Toilet' 'Obstructions On Streets, Sidewalks'
#  'Assault, Att. Homicide, W/ Other Weapon'
#  'Burglary, Hotel Room, Unlawful Entry' 'Robbery, Att., W/ Other Weapon'
#  'Assault, Aggravated, W/ Machine Gun' 'Heroin Offense'
#  'Marijuana, Transporting' 'Vehicle, Throwing Substance At'
#  'Kidnapping during Carjacking'
#  'Throwing Object at Common Carrier, Passenger or Freight'
#  'Vehicle, Open Container Of Alcohol In' 'Public Transit, Acts Against'
#  'Gambling' 'Accidental Lacerations'
#  'Access Card or Signature, Forgery of'
#  'Trespassing or Loitering Near Posted Industrial Property'
#  'Electrical  or Gas Lines, Interfering with'
#  'Firearm, Negligent Discharge' 'Perjury' 'Arson, Vacant Building'
#  'Assault, Att. Mayhem, W/ Other Weapon' 'Rape, Spousal'
#  'Civil Sidewalks, Citation'
#  'School Student or Employee Entering  Campus after Suspension or Dismissal'
#  'Assault, Att. Homicide, W/ Knife' 'Robbery, Att., Bank, W/ Force'
#  'Robbery,  ATM, Other Weapon' 'Theft, Vehicle Strip, $50-$200'
#  'Robbery,  ATM, Force.' 'Driving, Failure To Heed Red Light And Siren'
#  'Fire Protection Equipment, Tampering with'
#  'Loitering and Peeking into Inhabited Structure'
#  'Burglary Tools, Possession Of w/prior'
#  'Rail Transit, Entering, Remaining, or Hindering Operation of'
#  'Assault, Aggravated, W/ Semi Auto'
#  'Embezzlement, Grand Theft Leased Property'
#  'Robbery, Att., Chain Store, W/ Knife'
#  'Unemployment Insurance Act Violation'
#  'Purchase Female For The Purpose Of Prostitution'
#  'Theft, Purse Snatch, >$950' 'School, Public, Trespass'
#  'Prisoner, Rescuing From Lawful Custody' 'Theft, Trick & Device, Misd.'
#  'Phone Calls, Obscene' 'Suicide By Asphyxiation'
#  'Cocaine, Transportation' 'Robbery, Residence, W/ Force' 'Dog, Barking'
#  'Theft, Purse Snatch, $200-$950' 'Robbery, Bank, W/ Gun'
#  'Obstructing Public Thoroughfare  (or 647(c) PC)' 'Theft, Bicycle, Att.'
#  'Firearm Possession in School Zone' 'Caustic Chemical, Possession'
#  'Robbery, Bank, W/ Force' 'Permit Violation, Sidewalk Sales'
#  'Driving, Reckless, with Injury' 'Embezzlement, Petty Theft By Employee'
#  'Hallucinogenics Offense' 'Sexual Contact with Patient, former Patient'
#  'Permit Violation, Entertainment'
#  'Burglary, Apt Under Constr., Att. Forcible'
#  'Narcotics Addict, Failure To Register' 'Theft, Short Change, >$950'
#  'Fireworks, Throw at Person or Discharge in Crowd'
#  'Burglary, Flat Under Constr., Forcible Entry'
#  'Checks, Theft/Non-sufficient Funds, Felony'
#  'Kidnapping for Ransom or Extortion' 'Firefighter, Interfering with'
#  'Disturbing Religious Meetings' 'Robbery,  ATM, Force, Att.'
#  'Vending or Slot Machine, Unauthorized Use or Using Slugs'
#  'Robbery, Att., Residence, W/ Force' 'Robbery, Bank, W/ Knife'
#  'Sodomy (Adult Victim)' 'Stolen Computer, Possession'
#  'Robbery, Att., Comm. Establ. With Other Weapon'
#  'Suicide By Ingestion, Att.' 'Threatening School or Public Employee'
#  'Robbery, Residence, W/ Gun'
#  'Weapon, Deadly, Possession W/ Intent To Assault'
#  'Death, Non-manslaughter Vehicle Accident' 'Obscene Movies or Acts'
#  'Theft, Purse Snatch, $50-$200' 'Vehicle, Stolen, Bus'
#  'Embezzlement, Grand Theft Private Property'
#  'Vehicle, Disabled Placard Violation'
#  'Phone Calls in Violation of DVU Court Order' 'Suicide By Jumping, Att.'
#  'Suicide By Laceration/Stabbing, Att.' 'Suicide By Firearms'
#  'Shooting, Accidental' 'Assault, Aggravated, On Police Officer, W/ Force'
#  'Driving While Under The Influence Of Drugs, w/Injury'
#  'Burglary, Hotel Under Constr., Forcible Entry'
#  'Carjacking with a Dangerous Weapon' 'Methadone Offense'
#  'Robbery, Att., Chain Store, W/ Other Weapon' 'Marijuana, Furnishing'
#  'Theft, Bicycle, <$50, serial number known' 'Pandering'
#  'Assault, Mayhem, W/ Force' 'Robbery, Residence, W/ Other Weapon'
#  'Theft, Grand, of Firearm' 'Firearm, Possession of While Wearing Mask'
#  'Burglary, Flat Under Constr., Unlawful Entry'
#  'Fireworks, Possession of any within SF,  incl. "Safe & Sane"'
#  'Robbery, Service Station, W/ Knife'
#  'Malicious Mischief, Annoying/Fictitious Phone Calls' 'Riot, Inciting To'
#  'Robbery, Comml. Establ. W/ A Knife'
#  'School or Playground, Loitering About'
#  'Falsifying Judicial & Public Records & Documents'
#  'Stolen Electronics, Possession' 'Parking Meters, Damage to'
#  'Robbery, Service Station, W/ Force'
#  'Driving, Reckless, Motorcycle Takeover (Dirt Bike, ATV, OHV)' 'Suicide'
#  'Animal, without Proper Care or Attention' 'Theft, Boat'
#  'Money Laundering' 'Rape, Att., W/ Force'
#  'Weapon, Concealed, Loitering While Carrying'
#  'Peddling Without A License' 'Balloons, Electrically Conductive'
#  'Burglary, Warehouse Under Constr, Forcible Entry'
#  'Robbery, Att., Bank, W/ Gun' 'Assault on School Employee'
#  'Destructive Device, Exploding' 'Controlled Substance, Transportation'
#  'Theft, Drunk Roll, $50-$200' 'Fire Code Violation (general)'
#  'Firearms, Seizing at Scene of DVU' 'Theft, Animal, Att.'
#  'Methamphetamine, Transportation' 'Stolen Access Card, Possession'
#  'Public Health Order Violation, After Notification' 'Homicide, Drive-by'
#  'Arson, Police Vehicle' 'Retaking Goods from Peace Officer'
#  'Liquor Law Violation (general)' 'Suicide By Jumping'
#  'Theft, Motorcycle Strip, $50-$200' 'Robbery, Bank, W/ Other Weapon'
#  'Defrauding Of Vehicle Repairman' 'Solicits Lewd Act'
#  'Weapon, Deadly, Exhibiting to Resist Arrest'
#  'Sales of Cocaine Base/Schoolyard Trafficking Act Violation'
#  'Theft, Phone Booth, $50-$200' 'Suicide By Strangulation/Hanging, Att.'
#  'Assault, Mayhem, W/ Knife' 'Assault, W/ Poison' 'Military Ordinance'
#  'Wiretaps, Unauthorized' 'Robbery,  ATM, Other Weapon, Att.'
#  'Cloned Cellular Phone, Use' 'Suicide By Laceration/Stabbing'
#  'Robbery, Residence, W/ Knife' 'Theft, Vehicle Strip, <$50'
#  'Telephone or Telegraph Message, Sending False'
#  'Harbor & Navigations Code Violation (general)'
#  'Other Offenses Against Public Justice'
#  'Counterfeit/Forgery, Poss Drivers Lic Or Id Card'
#  'Merchandise Title Document Fraud' 'Stolen Checks, Possession'
#  'Embezzlement, Grand Theft By Brokers/Agents' 'Dog, Stray or Vicious'
#  'Riot' 'Civil Rights, incl. Injury, Threat, or Damage (Hate Crimes)'
#  'Theft of Written Instrument' 'Vandalism with Noxious Chemical'
#  'Counterfeiting, Coins Or Notes'
#  'Trade Secrets, Theft or Unauthorized Copying'
#  'Burglary, Safe, Apartment' 'Assault, Att. Mayhem, W/ Knife'
#  'Heroin, Transportation' 'Drug Lab Apparatus, Possession'
#  'Dissuading/Threatening Of A Witness' 'Trash, Placing On The Street'
#  'Theft, Motorcycle Strip, $200-$950' 'Assault, Mayhem, W/ Other Weapon'
#  'Robbery,  ATM, Knife'
#  'Human Trafficking (B)-Involuntary Servitude (not sex-related)'
#  'Gambling Devices, Possession' 'Gaming & Horse Racing (general)'
#  'Hazardous Materials, Dumping in Unauthorized Location'
#  'Records or Returns, False Entries'
#  'Weapon, Possessing in Public Building or Open Meeting'
#  'Soliciting, Aggressive' 'Crimes Involving Receipts or Titles'
#  'Financial Statements, False'
#  'Public Health Order Violation, Notification'
#  'Public Transit Crimes - Infractions' 'Assault, Att. Homicide, W/ Force'
#  'Crimes Against Revenue & Property of State'
#  'Loitering for Purpose of Prostitution' 'Theft, Pickpocket, Attempted'
#  'Demonstration, Video Evidence, Misc Investigation'
#  'Theft, Phone Booth, >$950' 'Explosives, Illegal Transportation'
#  'Probation Violation, DVU related'
#  'Weapon, Assault, Registration or Transfer Violation'
#  'Looting during State of Emergency'
#  'Assault to Commit Mayhem or Specific Sex Offenses'
#  'VIN, Alter Or Remove'
#  'Highway, Breaking Down or Removing Barrier, Sign, or Light'
#  'Accessory or Aid Or Harbor Felon' 'Homicide, W/ Sharp Object'
#  'Homicide, Excusable, W/ Sharp Object' 'Maintaining A Public Nuisance'
#  'Marijuana, Cultivating/Planting'
#  'Terrorizing by Arson or Explosive Device'
#  'Burglary, Hotel Under Constr., Unlawful Entry'
#  'Delivered Mail, Damage or Destruction of' "Megan's Law Notification"
#  'Destructive Device, Possession' 'Firearm, Tampering With Marks'
#  'Robbery, Att., Comm. Establ. W/ Knife' 'Vehicle, Recovered, Bus'
#  'Heroin, Sales' 'Burglary, Flat Under Constr., Att. Forcible'
#  'Accidental Burns' 'Assault, Mayhem, W/ Gun'
#  'Disturbance of Non-religious, Non-political Assembly'
#  'Firearm Transfer, Violation' 'Loitering, Obstructing'
#  'Theft, Coin Operated Machine, <$50' 'Assault, Att. Mayhem, W/ Force'
#  'Lodging in Park' 'Robbery, Att., Bank, W/ Other Weapon'
#  'Opium, Possession For Sale' 'Bathroom Hole, Looking through'
#  'Loitering near ATM' 'Eavesdropping Devices, Sale or Use'
#  'Gun Violence Restraining Order Violation'
#  'Controlled Substance, Presence Where Used' 'Pimping'
#  'SFMTA Parking and Control Officer' 'Driving, Drag Racing'
#  'Alcohol, Unlawful Transportation Of'
#  'Maintain Premise Where Narcotics Are Sold/used'
#  'Alcoholic Beverage, Procuring Sale of' 'Stolen Metals, Receiving'
#  'Theft, Coin Operated Machine, $50-$200' 'Dead Body, Removing Items from'
#  'Burglary, Safe,  Warehouse' 'Evading Payment of Railroad Fare'
#  'Burglary, Hotel Room, Att. Forcible Entry'
#  'Rape, Forcible, W/ Other Weapon'
#  'Robbery, Vehicle for Hire, Att., W/ Force'
#  'Push-cart Peddler Permit Violation'
#  'Manufacture or Sale of Counterfeit Goods'
#  'Burglary, Warehouse Under Constr, Att. Forcible' 'Incest'
#  'Methadone, Sale' 'Assault, Commission of While Armed'
#  'Escape of Prisoner From Hospital'
#  'Aerosol Paint & Marker Pens, Display & Storage'
#  'Theft, By Prostitute, $50-$200' 'Theft, Motorcycle Strip, <$50'
#  'Weapon, Deadly, Possession of to Violate 136.1 PC'
#  'Theft, Phone Booth, $200-$950'
#  'Cable TV Connection or Decoding Device, Unauthorized'
#  'Civil Sidewalks, Violation'
#  'Loitering Around Public Toilet For Lewd Act' 'Suicide By Fire'
#  'Trespass within 30 days of Credible Threat'
#  'Prescription, Forge Or Alter (4390 B&P)'
#  'Theft, By Prostitute, $200-$400'
#  'Forgery, Government Or Corporate Seals'
#  'Permit Violation, Police (general)' 'Cocaine, Sale'
#  'Theft, Drunk Roll, <$50' 'Embezzlement, Grand Theft By Property Carrier'
#  'Soliciting to Visit House Of Prostitution' 'Assault, By Police Officers'
#  'Hazardous Materials,  Dump any Substance into Water'
#  'Aerosol Container; Sale, Purchase or Possession of'
#  'Impersonating Public Utility Member'
#  'Access Card Information, Publication of'
#  'Embezzlement, Petty Theft Private Property' 'Abortion, Unlawful'
#  'Robbery, Att., Residence, W/ Knife'
#  'Theft, Coin Operated Machine, >$950'
#  'Police Broadcast, Interception to Commit Crime' 'Bribery Of Witnesses'
#  'Suicide By Ingestion' 'Soliciting Commission Of A Crime'
#  'Robbery, Att., Service Station, W/ Gun' 'Fire Bomb, Possession or Use'
#  'Theft, Drunk Roll, Att.'
#  'SFMTA Employee-Non Operator/Station Agent-Other Employee'
#  'Terrorizing by Interfering with Religious Worship'
#  'Embezzlement, Grand Theft By Collector'
#  'Permit Violation, Advertising Distributors'
#  'Armor Penetrating Ammunition, Possession'
#  'Manslaughter, Accidental, W/ Other Weapon'
#  'Terrorizing by Marking Private Property'
#  'Trespassing On Railroad Trains' 'Escape From Hospital With Force'
#  'Highway, Injuring' 'Assault, Att. Homicide, Explosives'
#  'Robbery, Att., Service Station W/ Other Weapon'
#  'Destructive Device, Possession of Materials' 'Labor Code Violation'
#  'Legal Instruments, Uttering False Checks, etc. (misd.)'
#  'Alcohol, Furnish or Sell to Intox. Person'
#  'Dog, Fighting;  Owning, Fighting, or Attending Fight'
#  'Parking Meter, Unlawful Operation or Use of Slugs'
#  'Hallucinogenic, Transportation'
#  'Wearing Mask or Disguise for Unlawful Purpose' 'Barbiturates Offense'
#  'Burglary, Safe,  Hotel' 'Lynching by Riot'
#  'Alcohol, Sale Of After Hours' 'Violation of Civil Gang Injunction'
#  'Prescription, Forge Or Alter (11368 H&S)'
#  'Advertisements, Affixing To Poles' 'Escape or Assisting Escape'
#  'Theft, By Prostitute, <$50' 'Lotteries (general)'
#  'Weapon, Taking or Attempting to Take from Peace Officer'
#  'Service of Documents Related to a Civil Drug Abatement and/or Public Nuisance Action'
#  'Rape, Assault To, W/ Other Weapon'
#  "Assault or Attempted Murder Upon Gov't Officers"
#  'Pyrotechnic Explosive Device - Barrel Bomb' 'Suicide By Drowning, Att.'
#  'Endless Chain Schemes, Ponzi Schemes' 'Homicide By Sniping'
#  'Suicide By Fire, Att.' 'Citizenship Document, Using False'
#  'Burglary, Warehouse Under Constr, Unlawful Entry'
#  'Rape, Assault To, W/ Sharp Object'
#  'Telephone or Telegraph Messages, Altering'
#  'Hazardous Materials, Spill Load'
#  'Embezzlement, Petty Theft By Brokers/Agents'
#  'Gambling Paraphernalia, Possession' 'Barbiturates, Transportation'
#  'Homicide, W/ Force' 'Theft, Purse Snatch, Att.'
#  'Robbery, Att., Bank, W/ Knife' 'Barbiturates, Possession'
#  'Firearm Silencer, Possession' 'Massage Establishment Permit Violation'
#  'Procurement, Pimping, & Pandering' 'Amphetamine, Transportation'
#  'Loud Speakers, Unauthorized Use of' 'Arson with Great Bodily Injury'
#  'Indecent Exposure, Prostitution Related' 'Homicide, W/ Other Weapon'
#  'Embezzlement, Petty Theft, Leased Property' 'Hotel Violations'
#  'Articles With ID Removed, Possession of'
#  'Burglary, Safe, Other, with Explosives'
#  'Robbery, Vehicle for Hire, Att., W/ Other Weapon'
#  'Hypodermic Needle or Syringe, Possession'
#  'Contraband, Taking Into A Reformatory'
#  'Threat to State Official or Judge' 'Chop Shop, Own or Operate'
#  'Robbery, Att., Service Station, W/ Knife'
#  'Sale or Manufacture of Deceptive ID' 'Rape, Forcible, W/ Sharp Object'
#  'Suicide By Firearms, Att.' 'Lodging, Registering w/False Name'
#  'Burglary, Safe, Warehouse, with Explosives'
#  'Suicide By Asphyxiation, Att.'
#  'Soliciting Customer to Purchase Alcoholic Beverage'
#  'Rape, Forcible, W/ Gun' 'Guide Dog, Interfering with'
#  'Robbery, Att., Service Station W/ Force'
#  'Robbery, Att., Residence, W/ Other Weapon' 'Animal, Poisoning of'
#  'Embezzlement, Petty Theft By Property Carrier'
#  'Assault, Att. Mayhem, W/ Gun' 'Rape, Assault To, W/ Gun'
#  'Sale of Satellite Telephone Numbers'
#  'Bribery or Gratuity,  Public Employees'
#  'Jail Property, Destroying (SFPD only)'
#  'Insured Property, Destruction to Defraud Insurer'
#  'Impersonating Fire Department Member'
#  'Barbiturates, Possession For Sale' 'Rape, Att., W/ Gun']

# %%
# show min max date
print(crime['incident_datetime'].min())
print(crime['incident_datetime'].max())
# Out:
# 2022-01-01 00:00:00
# 2025-05-31 23:20:00

# %%
print(crime['analysis_neighborhood'].unique())
# Out:
# ['Marina' 'Western Addition' 'Bernal Heights' 'Oceanview/Merced/Ingleside'
#  'Chinatown' 'Hayes Valley' 'Outer Richmond' 'Tenderloin' 'Mission Bay'
#  'Sunset/Parkside' 'Mission' 'Financial District/South Beach'
#  'Pacific Heights' 'Nob Hill' 'South of Market' 'West of Twin Peaks'
#  'Bayview Hunters Point' 'Haight Ashbury' 'Excelsior' 'Russian Hill'
#  'Portola' 'Castro/Upper Market' 'Lakeshore' 'Outer Mission'
#  'Lincoln Park' 'Golden Gate Park' 'North Beach' 'Potrero Hill'
#  'Inner Richmond' 'Lone Mountain/USF' 'Glen Park' 'Twin Peaks'
#  'Inner Sunset' 'Noe Valley' 'Presidio Heights' 'Visitacion Valley'
#  'Japantown' 'Seacliff' 'Presidio' 'Treasure Island' 'McLaren Park']

# %% [markdown]
# # Transforming the data

# %% [markdown]
# Encoding day of the week

# %%
# encode
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
crime['day_of_week_encoded'] = le.fit_transform(crime['incident_day_of_week'])

# %%
#print unique day of week
print(crime['day_of_week_encoded'].unique())
# Out:
# [3 5 2 1 0 6 4]

# %% [markdown]
# Categorizing dangerous crimes

# %%
# dangerous crimee
high_risk_categories = { 'Assault', 'Arson', 'Burglary', 'Larceny Theft',
  'Robbery', 'Weapons Offense','Homicide', 'Sex Offense', 'Rape',
  'Human Trafficking (A), Commercial Sex Acts',
  'Human Trafficking, Commercial Sex Acts', 'Weapons Offence',
  'Human Trafficking (B), Involuntary Servitude'
}

high_risk_subcategories = {'Simple Assault', 'Aggravated Assault', 'Arson',
 'Burglary - Other', 'Larceny - From Vehicle', 'Weapons Offense' ,
 'Robbery - Commercial', 'Robbery - Other','Burglary - Commercial',
 'Burglary - Residential','Larceny Theft - Pickpocket',
 'Burglary - Hot Prowl', 'Robbery - Street', 'Homicide','Sex Offense',
 'Rape','Rape - Attempted', 'Larceny Theft - Purse Snatch',
 'Robbery - Residential','Human Trafficking, Commercial Sex Acts'
 'Manslaughter', 'Homicide - Excusable'
 }
# Apply logic: if either category OR subcategory is high-risk
def assign_risk(row):
    if (row['incident_subcategory'] in high_risk_subcategories) or (row['incident_category'] in high_risk_categories):
        return 1  # High-risk
    return 0  # Low-risk

# Apply row-wise
crime['risk_level'] = crime.apply(assign_risk, axis=1)

# %%
# prompt: create a heatmap for start_date='2025-01-01', end_date='2025-05-28' for incident_category in  high_risk_categories

def create_filtered_heatmap(dataframe, start_date, end_date, incident_categories):
    """
    Creates a heatmap of crime incidents for multiple incident categories within a date range.

    Args:
        dataframe (pd.DataFrame): The crime data DataFrame.
        start_date (str): Start date for filtering (YYYY-MM-DD).
        end_date (str): End date for filtering (YYYY-MM-DD).
        incident_categories (list): A list of incident categories to filter by.

    Returns:
        folium.Map: The Folium map object with the heatmap layer.
    """
    # Filter by date range
    filtered_df = dataframe[
        (dataframe['incident_datetime'] >= start_date) &
        (dataframe['incident_datetime'] <= end_date)
    ].copy()

    # Filter by incident categories
    filtered_df = filtered_df[filtered_df['incident_category'].isin(incident_categories)]

    # Ensure there are data points after filtering
    if filtered_df.empty:
        print("No data points found for the selected filters.")
        # Create a base map even if empty
        m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
        return m

    # Create a list of latitude and longitude pairs for the heatmap
    heat_data = filtered_df[['latitude', 'longitude']].values.tolist()

    # Create a base map centered around the San Francisco area
    m = folium.Map(location=[filtered_df['latitude'].mean(), filtered_df['longitude'].mean()], zoom_start=12)

    # Add the heatmap layer
    HeatMap(heat_data).add_to(m)

    return m

# Convert the set to a list for the function
high_risk_categories_list = list(high_risk_categories)

# Create the heatmap
high_risk_heatmap = create_filtered_heatmap(
    crime,
    start_date='2025-05-01',
    end_date='2025-05-28',
    incident_categories=high_risk_categories_list
)

# Display the heatmap (in Jupyter/Colab, just having the variable at the end displays it)
high_risk_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5a2a6bb9ccf5dead969d58fb9b00440 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5a2a6bb9ccf5dead969d58fb9b00440&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5a2a6bb9ccf5dead969d58fb9b00440 = L.map(
#                 &quot;map_c5a2a6bb9ccf5dead969d58fb9b00440&quot;,
#                 {
#                     center: [37.768523549858905, -122.42302180209876],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fc0c7130b8d9a8e4a97960da192dd33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5fc0c7130b8d9a8e4a97960da192dd33.addTo(map_c5a2a6bb9ccf5dead969d58fb9b00440);
#
#
#             var heat_map_c637b1224f851008fdd57a4d732cbc08 = L.heatLayer(
#                 [[37.76560592651367, -122.41048431396484], [37.76960372924805, -122.42630767822266], [37.77516174316406, -122.40363311767578], [37.78378677368164, -122.39893341064452], [37.74312210083008, -122.4214859008789], [37.78423690795898, -122.41770935058594], [37.78795623779297, -122.41341400146484], [37.78558349609375, -122.41461944580078], [37.77305221557617, -122.40320587158205], [37.73927688598633, -122.4002456665039], [37.80561828613281, -122.41360473632812], [37.764930725097656, -122.48904418945312], [37.78248977661133, -122.4458236694336], [37.76578140258789, -122.40753173828124], [37.78822326660156, -122.4202117919922], [37.75550079345703, -122.41765594482422], [37.760887145996094, -122.43499755859376], [37.78890609741211, -122.433837890625], [37.80727767944336, -122.41561889648438], [37.76148986816406, -122.4250259399414], [37.74885177612305, -122.4212875366211], [37.8051986694336, -122.43209075927734], [37.78097152709961, -122.40870666503906], [37.78313827514648, -122.44452667236328], [37.78393173217773, -122.41259765625], [37.77516174316406, -122.40363311767578], [37.77516174316406, -122.40363311767578], [37.78661346435547, -122.40640258789062], [37.78423690795898, -122.41770935058594], [37.78641128540039, -122.40803527832033], [37.7888069152832, -122.4118881225586], [37.74312210083008, -122.4214859008789], [37.77348709106445, -122.46481323242188], [37.78641128540039, -122.40803527832033], [37.80727767944336, -122.41561889648438], [37.78313827514648, -122.44452667236328], [37.74312210083008, -122.4214859008789], [37.74312210083008, -122.4214859008789], [37.730316162109375, -122.40470886230467], [37.78248977661133, -122.4458236694336], [37.75865173339844, -122.50365447998048], [37.77755355834961, -122.40991973876952], [37.78641128540039, -122.40803527832033], [37.74312210083008, -122.4214859008789], [37.746490478515625, -122.42035675048828], [37.740570068359375, -122.48948669433594], [37.80350112915039, -122.42162322998048], [37.790565490722656, -122.40557098388672], [37.74312210083008, -122.4214859008789], [37.781864166259766, -122.4138641357422], [37.74312210083008, -122.4214859008789], [37.71023941040039, -122.43498229980467], [37.73927688598633, -122.4002456665039], [37.80048751831055, -122.4088363647461], [37.7758903503418, -122.41513061523438], [37.74312210083008, -122.4214859008789], [37.78061294555664, -122.4237289428711], [37.769798278808594, -122.44857788085938], [37.73152923583984, -122.38195037841795], [37.74312210083008, -122.4214859008789], [37.775333404541016, -122.39720916748048], [37.769798278808594, -122.44857788085938], [37.749488830566406, -122.41065979003906], [37.74312210083008, -122.4214859008789], [37.780494689941406, -122.43214416503906], [37.74312210083008, -122.4214859008789], [37.74312210083008, -122.4214859008789], [37.7758903503418, -122.41513061523438], [37.7867317199707, -122.4045867919922], [37.785491943359375, -122.40785217285156], [37.74312210083008, -122.4214859008789], [37.73460006713867, -122.39034271240234], [37.77853775024414, -122.42499542236328], [37.775272369384766, -122.41590881347656], [37.77164077758789, -122.42174530029295], [37.730316162109375, -122.40470886230467], [37.74312210083008, -122.4214859008789], [37.7758903503418, -122.41513061523438], [37.74312210083008, -122.4214859008789], [37.739234924316406, -122.40692901611328], [37.72114181518555, -122.39832305908205], [37.78582763671875, -122.4014892578125], [37.78641128540039, -122.40803527832033], [37.79301452636719, -122.4161148071289], [37.7420539855957, -122.4981918334961], [37.74971771240234, -122.40689849853516], [37.784141540527344, -122.410949707

# %%
# Create a heatmap for a specific timeframe and category
filtered_heatmap = create_crime_heatmap(crime, start_date='2025-01-01', end_date='2025-05-28', incident_category=high_risk_categories)
filtered_heatmap
# Out:
# No data points found for the selected filters.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_143589ed11f1c23061e99b56c77eb8d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_143589ed11f1c23061e99b56c77eb8d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_143589ed11f1c23061e99b56c77eb8d8 = L.map(
#                 &quot;map_143589ed11f1c23061e99b56c77eb8d8&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6457efac55763ba12946058ec0e5a190 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6457efac55763ba12946058ec0e5a190.addTo(map_143589ed11f1c23061e99b56c77eb8d8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

# --- Clean time ---
crime['incident_time'] = crime['incident_time'].astype(str)
crime['incident_time_dt'] = pd.to_datetime(crime['incident_time'], format='%H:%M', errors='coerce')
crime['incident_hour'] = crime['incident_time_dt'].dt.hour
crime['incident_minute'] = crime['incident_time_dt'].dt.minute
crime = crime.dropna(subset=['incident_hour', 'incident_minute'])

# Convert string date to datetime
crime['incident_datetime'] = pd.to_datetime(crime['incident_datetime'])

# 1. Recency weight: more recent = higher weight
most_recent = crime['incident_datetime'].max()
crime['days_ago'] = (most_recent - crime['incident_datetime']).dt.days
crime['recency_weight'] = 1/(1+((crime['days_ago'])/ 180))  # sigmoid like

# 2. Severity weight: make high-risk crimes more important
def compute_severity(subcat):
    subcat = str(subcat).lower()  # lowercase for easy matching

    # Keyword-based scoring
    if 'homicide' in subcat or 'manslaughter' in subcat:
        return 3
    elif 'rape' in subcat or 'sex' in subcat:
        return 2.5
    elif 'robbery' in subcat:
        return 2.25
    elif 'assault' in subcat:
        return 2
    elif 'arson' in subcat or 'weapons' in subcat:
        return 1.75
    elif 'burglary' in subcat:
        return 1.5
    elif 'larceny' in subcat or 'theft' in subcat:
        return 1.5
    elif 'vandalism' in subcat or 'property' in subcat:
        return 1
    else:
        return 1  # default weight


crime['severity_weight'] = crime['incident_subcategory'].apply(compute_severity)

# 3. Final weight = product
crime['weight'] = crime['recency_weight'] * crime['severity_weight']

# cap
crime['weight'] = np.minimum(crime['weight'], 5)

# %% [markdown]
# Tuning for Threshold's

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

# --- Encode day of week ---
crime['day_of_week_encoded'] = crime['day_of_week_encoded'].astype(int)
ohe = OneHotEncoder(sparse_output=False, categories='auto')
day_encoded = ohe.fit_transform(crime[['day_of_week_encoded']])
day_labels = ohe.get_feature_names_out(['day_of_week_encoded'])
day_df = pd.DataFrame(day_encoded, columns=day_labels, index=crime.index)

# --- Combine features ---
model_df = pd.concat([
    crime[['incident_hour', 'incident_minute', 'latitude', 'longitude', 'risk_level', 'weight']],
    day_df
], axis=1)

# --- Train/test split ---
X = model_df.drop(['risk_level', 'weight'], axis=1)
y = model_df['risk_level']
weights = model_df['weight']

X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(
    X, y, weights, stratify=y, test_size=0.2, random_state=42
)

# --- Fit classifier using weights ---
clf = RandomForestClassifier(class_weight=None, random_state=42)
clf.fit(X_train, y_train, sample_weight=w_train)

# --- Score & threshold tuning ---
y_probs = clf.predict_proba(X_test)[:, 1]

thresholds = [0.3, 0.4, 0.5, 0.6, 0.7]
for t in thresholds:
    y_pred_thresh = (y_probs > t).astype(int)
    precision = precision_score(y_test, y_pred_thresh)
    recall = recall_score(y_test, y_pred_thresh)
    f1 = f1_score(y_test, y_pred_thresh)

    print(f"Threshold: {t}")
    print(f"  Precision: {precision:.2f}")
    print(f"  Recall:    {recall:.2f}")
    print(f"  F1 Score:  {f1:.2f}\n")
# Out:
# Threshold: 0.3
#   Precision: 0.52
#   Recall:    0.78
#   F1 Score:  0.63
#
# Threshold: 0.4
#   Precision: 0.55
#   Recall:    0.67
#   F1 Score:  0.60
#
# Threshold: 0.5
#   Precision: 0.57
#   Recall:    0.54
#   F1 Score:  0.56
#
# Threshold: 0.6
#   Precision: 0.61
#   Recall:    0.40
#   F1 Score:  0.48
#
# Threshold: 0.7
#   Precision: 0.63
#   Recall:    0.28
#   F1 Score:  0.39

# %%
# ors routing
# !pip install openrouteservice folium
# Out:
# Collecting openrouteservice
#   Downloading openrouteservice-2.3.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.6)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.11/dist-packages (from openrouteservice) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (2025.4.26)
# Downloading openrouteservice-2.3.3-py3-none-any.whl (33 kB)
# Installing collected packages: openrouteservice
# Successfully installed openrouteservice-2.3.3

# %%
# from secrets
import openrouteservice
from google.colab import userdata
key = userdata.get('ors_key')
ors_client = openrouteservice.Client(key=key)

# %%
# route geometry from ORS
def get_route_coords(start, end):
    coords = [start, end]  # (lon, lat) pairs
    route = ors_client.directions(coords, profile='foot-walking', format='geojson')
    return route['features'][0]['geometry']['coordinates']  # list of [lon, lat]

# %% [markdown]
# Testing

# %%
# Sample coordinates in San Francisco: (longitude, latitude)
start = (-122.4194, 37.7749)  # SF downtown
end = (-122.446, 37.8017)     # Marina

try:
    route = ors_client.directions(
        coordinates=[start, end],
        profile='foot-walking',
        format='geojson'
    )

    coords = route['features'][0]['geometry']['coordinates']
    print(f"✅ ORS request successful. Route has {len(coords)} points.")
except openrouteservice.exceptions.ApiError as e:
    print(f"❌ ORS API error: {e}")
except Exception as e:
    print(f"❌ General error: {e}")
# Out:
# ✅ ORS request successful. Route has 118 points.

# %% [markdown]
# Creating address to coordinates function

# %%
import requests

def geocode_address(address):
    url = "https://api.openrouteservice.org/geocode/search"
    params = {
        "api_key": key,
        "text": address,
        "boundary.country": "US",
        "size": 1
    }
    response = requests.get(url, params=params)
    data = response.json()
    try:
        coords = data['features'][0]['geometry']['coordinates']  # [lon, lat]
        return coords
    except (IndexError, KeyError):
        print(f"❌ Could not geocode: {address}")
        return None

# %% [markdown]
# Map plotting function with Folium library

# %%
# map
import folium
def plot_route_on_map(coords, start_coords, end_coords, risk_score, risk_per_point, rerouted=False):
    # Flip coords for folium
    latlon_coords = [(lat, lon) for lon, lat in coords]

    # Create map centered on start
    m = folium.Map(location=[start_coords[1], start_coords[0]], zoom_start=14)

    # Polyline for entire route
    color = "red" if rerouted else "blue"
    folium.PolyLine(latlon_coords, color=color, weight=5, opacity=0.8).add_to(m)

    # Mark start and end
    folium.Marker(latlon_coords[0], popup="Start", icon=folium.Icon(color="green")).add_to(m)
    folium.Marker(latlon_coords[-1], popup="End", icon=folium.Icon(color="orange")).add_to(m)

    # Midpoint marker with average risk
    folium.Marker(
        location=latlon_coords[len(latlon_coords) // 2],
        popup=f"Avg Risk: {risk_score:.2f}",
        icon=folium.Icon(color="red" if rerouted else "blue")
    ).add_to(m)

    # Per-point risk markers (subtle)
    for (lat, lon), risk in zip(latlon_coords, risk_per_point):
        folium.CircleMarker(
            location=(lat, lon),
            radius=4,
            fill=True,
            fill_opacity=0.6,
            color="crimson" if risk > 0.5 else "gray",
            tooltip=f"Risk: {risk:.2f}"
        ).add_to(m)

    return m

# %% [markdown]
# Rerouting function for danger > 0.5

# %%
# Re-import required dependencies after environment reset
import pandas as pd
import numpy as np
from shapely.geometry import Polygon, mapping
from shapely.ops import unary_union

# Multi-attempt rerouting wrapper that tries different buffer sizes to minimize route risk
# buffer size = groups all risky areas into a polygon of coords tries to categorise areas to avoid,
# then reroutes to different area
# recursively iterates through different routes, and those occurring in the polygon are ignored
def iterative_reroute_min_risk(
    coords, start, end, hour, minute, day_str,
    clf, ohe, day_labels, buffer_sizes=[0.001, 0.0015, 0.002], risk_threshold=0.5
):
    def day_index(d):
        return ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'].index(d)

    idx = day_index(day_str)
    day_vector = ohe.transform(pd.DataFrame({'day_of_week_encoded': [idx]})).flatten()
    day_cols = ['incident_hour', 'incident_minute', 'latitude', 'longitude'] + list(day_labels)

    # Score original route
    original_scores = []
    for lon, lat in coords:
        features = [hour, minute, lat, lon] + day_vector.tolist()
        row = pd.DataFrame([features], columns=day_cols)
        prob = clf.predict_proba(row)[0, 1]
        original_scores.append(prob)

    original_risk = sum(original_scores) / len(original_scores)

    best_risk = original_risk
    best_coords = coords
    best_scores = original_scores
    best_buffer = None

    for buffer_size in buffer_sizes:
        try:
            # Identify top 20% riskiest points
            scores = []
            for lon, lat in coords:
                features = [hour, minute, lat, lon] + day_vector.tolist()
                row = pd.DataFrame([features], columns=day_cols)
                prob = clf.predict_proba(row)[0, 1]
                scores.append(prob)
            top_idxs = np.argsort(scores)[-int(len(scores) * 0.2):]
            avoid_coords = [[coords[i][0], coords[i][1]] for i in top_idxs]

            # Buffer and merge
            polygons = [
                Polygon([
                    (lon + buffer_size, lat + buffer_size),
                    (lon - buffer_size, lat + buffer_size),
                    (lon - buffer_size, lat - buffer_size),
                    (lon + buffer_size, lat - buffer_size),
                    (lon + buffer_size, lat + buffer_size)
                ])
                for lon, lat in avoid_coords
            ]
            merged_polygon = unary_union(polygons)
            avoid_geojson = mapping(merged_polygon)

            # ORS call
            route = ors_client.directions(
                coordinates=[start, end],
                profile='foot-walking',
                format='geojson',
                options={"avoid_polygons": avoid_geojson}
            )
            new_coords = route['features'][0]['geometry']['coordinates']

            # Score new route
            new_scores = []
            for lon, lat in new_coords:
                features = [hour, minute, lat, lon] + day_vector.tolist()
                row = pd.DataFrame([features], columns=day_cols)
                prob = clf.predict_proba(row)[0, 1]
                new_scores.append(prob)

            avg_risk = sum(new_scores) / len(new_scores)
            if avg_risk < best_risk:
                best_risk = avg_risk
                best_coords = new_coords
                best_scores = new_scores
                best_buffer = buffer_size
        except Exception:
            continue

    return {
        "coords": best_coords,
        "avg_risk": best_risk,
        "risk_per_point": best_scores,
        "was_rerouted": best_coords != coords,
        "buffer_used": best_buffer,
        "original_risk": original_risk
    }

# %%
# need
def day_index(day_str):
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    return days.index(day_str)

# %% [markdown]
# Assessing Route function using score_route

# %%
def score_route(coords, hour, minute, day_str):
    # Round user-input minute
    minute_rounded = round_to_nearest_15(minute)

    # Convert day string to encoded and one-hot vector
    idx = day_index(day_str)
    day_encoded_array = ohe.transform(pd.DataFrame({'day_of_week_encoded': [idx]}))
    day_vector = day_encoded_array.flatten().tolist()

    risks = []
    for lon, lat in coords:
        features = [hour, minute_rounded, lat, lon] + day_vector
        columns = ['incident_hour', 'incident_minute', 'latitude', 'longitude'] + list(day_labels)

        if len(features) != len(columns):
            print(f"Feature mismatch: {len(features)} features vs {len(columns)} columns")
            continue

        row = pd.DataFrame([features], columns=columns)
        prob = clf.predict_proba(row)[0, 1]
        risks.append(prob)

    avg_risk = sum(risks) / len(risks) if risks else 0
    return avg_risk, risks

# %%
def assess_route(start, end, hour, minute, day_str, threshold=0.5):
    coords = get_route_coords(start, end)
    avg_risk, risk_per_point = score_route(coords, hour, minute, day_str)

    if avg_risk > threshold:
        print(f"⚠️ Route risk ({avg_risk:.2f}) exceeds threshold {threshold} — rerouting...")
    else:
        print(f"✅ Route is safe with risk score: {avg_risk:.2f}")

    return coords, avg_risk, risk_per_point

# %%
# add bining for 15-30 minute interval so avoids individual noise

# %%
# Re-import necessary libraries after kernel reset
import pandas as pd
import numpy as np
from shapely.geometry import Polygon, mapping
from shapely.ops import unary_union

# Define time rounding function
def round_to_nearest_15(minute):
    return int(round(minute / 15.0) * 15) % 60

# Define day index lookup
def day_index(d):
    return ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'].index(d)

# %% [markdown]
# # Here we test the geocode and map output

# %%
start_address = "1342 Irving Street, San Francisco"
end_address = "327 Lincoln Way, San Francisco"
hour = 2
minute = 15
day_str = "Saturday"

start_coords = geocode_address(start_address)
end_coords = geocode_address(end_address)

# Check the unique values in crime['incident_day_of_week'] before fitting the encoder
# Make sure you use the string day name here, as assess_route now handles the encoding
coords, avg_risk, risk_per_point = assess_route(start_coords, end_coords, hour, minute, day_str)
# Out:
# ⚠️ Route risk (0.74) exceeds threshold 0.5 — rerouting...

# %% [markdown]
# rerouting with risk minimization

# %%
result = iterative_reroute_min_risk(
    coords, start_coords, end_coords, hour, minute, day_str,
    clf=clf, ohe=ohe, day_labels=day_labels
)

result = iterative_reroute_min_risk(
    coords, start_coords, end_coords, hour, minute, day_str,
    clf=clf, ohe=ohe, day_labels=day_labels
)

print(f"🧭 Best route risk: {result['avg_risk']:.2f}")
if result["was_rerouted"] and result["avg_risk"] <= 0.5:
    print(f"✅ Rerouted with buffer: {result['buffer_used']}")
else:
    if result["avg_risk"] > 0.5:
        print("🚨 All paths are risky — consider waiting to walk.")
    else:
        print("👍 Original path is within safe limits.")

# Visualize
map_obj = plot_route_on_map(
    result["coords"],
    start_coords,
    end_coords,
    risk_score=result["avg_risk"],
    risk_per_point=result["risk_per_point"],
    rerouted=result["was_rerouted"]
)
map_obj
# Out:
# 🧭 Best route risk: 0.73
# 🚨 All paths are risky — consider waiting to walk.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_611ce643392ec57f50dea402e550e846 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_611ce643392ec57f50dea402e550e846&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_611ce643392ec57f50dea402e550e846 = L.map(
#                 &quot;map_611ce643392ec57f50dea402e550e846&quot;,
#                 {
#                     center: [37.76391, -122.472468],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc6f9813a939dc4b402b959710557261 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc6f9813a939dc4b402b959710557261.addTo(map_611ce643392ec57f50dea402e550e846);
#
#
#             var poly_line_b5782aeb3826e6916d2c98158b2b0dc1 = L.polyline(
#                 [[37.763779, -122.472459], [37.763813, -122.471682], [37.76386, -122.470615], [37.762094, -122.470493], [37.762099, -122.470392], [37.762063, -122.470389], [37.761935, -122.47038], [37.761901, -122.470378], [37.76194, -122.469508], [37.761944, -122.469409], [37.761949, -122.469303], [37.761986, -122.468435], [37.761987, -122.468422], [37.761992, -122.468337], [37.761995, -122.468268], [37.761996, -122.468236], [37.762034, -122.467358], [37.762038, -122.467266], [37.760371, -122.467153], [37.760373, -122.467085], [37.760374, -122.467062], [37.760364, -122.467043], [37.7604, -122.466184], [37.760409, -122.466173], [37.760409, -122.46615], [37.760413, -122.466078], [37.760416, -122.466002], [37.760417, -122.465985], [37.760406, -122.465984], [37.76046, -122.46511], [37.760462, -122.46509], [37.760465, -122.465005], [37.760466, -122.464938], [37.760467, -122.464913], [37.760502, -122.464052], [37.760503, -122.464026], [37.760506, -122.463934], [37.760509, -122.463858], [37.76051, -122.463838], [37.760545, -122.462974], [37.760556, -122.462965], [37.760556, -122.462952], [37.760559, -122.462866], [37.760561, -122.462789], [37.760545, -122.462762], [37.760584, -122.461903], [37.760602, -122.461891], [37.762265, -122.462004], [37.762277, -122.462017], [37.76229, -122.462017], [37.762368, -122.462025], [37.762444, -122.462031], [37.762456, -122.462033], [37.762465, -122.462025], [37.762467, -122.46201], [37.762477, -122.461929], [37.762485, -122.461856], [37.762487, -122.461838], [37.764149, -122.461955], [37.764155, -122.461948], [37.764178, -122.461936], [37.764243, -122.461945], [37.764305, -122.461953], [37.764323, -122.461954], [37.764337, -122.461971], [37.764683, -122.461989], [37.7651, -122.462019], [37.765114, -122.462009], [37.76513, -122.462014], [37.765178, -122.462018], [37.765219, -122.462021], [37.765237, -122.462018], [37.765244, -122.462031], [37.766006, -122.462085], [37.766022, -122.462071], [37.766039, -122.46163]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_611ce643392ec57f50dea402e550e846);
#
#
#             var marker_b471ab1178f11bdd39f0591143b89c57 = L.marker(
#                 [37.763779, -122.472459],
#                 {
# }
#             ).addTo(map_611ce643392ec57f50dea402e550e846);
#
#
#             var icon_d9d124c98b5241440b0e4911b50f76df = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1789cc96a4dce9cfb4be82bf551b667a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6f2eaf86123fd703aae3f54be3aab9b = $(`&lt;div id=&quot;html_e6f2eaf86123fd703aae3f54be3aab9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_1789cc96a4dce9cfb4be82bf551b667a.setContent(html_e6f2eaf86123fd703aae3f54be3aab9b);
#
#
#
#         marker_b471ab1178f11bdd39f0591143b89c57.bindPopup(popup_1789cc96a4dce9cfb4be82bf551b667a)
#         ;
#
#
#
#
#                 marker_b471ab1178f11bdd39f0591143b89c57.setIcon(icon_d9d124c98b5241440b0e4911b50f76

# %% [markdown]
# save in joblib

# %%
# at end of your notebook
import os, joblib
os.makedirs("models", exist_ok=True)

joblib.dump(clf, "models/risk_model.joblib")
joblib.dump(ohe, "models/encoder.joblib")
# Out:
# ['models/encoder.joblib']

# %%
# download folder
from google.colab import drive
drive.mount('/content/drive')
#Code For going to Drive you want to download :
# Out:
# Mounted at /content/drive

# %%
# file
# %cd /content/models

#Code to turn Folder into zip :
# !zip -r models.zip /content/models
# Code To download zip folder :
from google.colab import files
files.download('models.zip')
# Out:
# /content/models
#   adding: content/models/ (stored 0%)
#   adding: content/models/risk_model.joblib (deflated 66%)
#   adding: content/models/encoder.joblib (deflated 39%)
